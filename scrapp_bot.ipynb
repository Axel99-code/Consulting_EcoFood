# %%
"""
https://scrapbot.link/
PREPARATIVOS DEL BOT SCRAPPER

links de posible uso:
Scielo: bibliografia completa de multiples fuentes
https://www.scielo.org.ar/scielo.php?script=sci_arttext&pid=S1852-73372022000100090

Segunda encuensta 2021 de nutricion y salud.
https://datos.salud.gob.ar/dataset/ennys2/archivo/5ef1b908-a038-4785-9f5d-eb5036c6adce

Los 10 mejores restaurantes de buenos aires
https://www.tripadvisor.com.ar/Restaurants-g312741-c10679-Buenos_Aires_Capital_Federal_District.html

PedidosYa restaurantes Comidas saludables Buenos aires
https://www.pedidosya.com.ar/restaurantes?address=Buenos%20Aires&areaId=18773&lat=-34.6036844&lng=-58.3815591&query=saludable

guia oleo
https://www.guiaoleo.com/buenos-aires/restaurants
"""
# Out:
# hola mundo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de ejemplo
url = "https://www.guiaoleo.com/buenos-aires/restaurants"

# Paso 1: Descarga de la página
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup)

# Paso 2: Extraccion de reseñas (ajusta selectores según la página real)
# reseñas = []
# for review in soup.select(".review"):  # ejemplo de clase CSS
#     texto = review.get_text(strip=True)
#     reseñas.append(texto)

# Paso 3: Guardar en DataFrame
# df = pd.DataFrame(reseñas, columns=["comentario"])
# print(df.head())
# Out:
# <!DOCTYPE html>
#  <html lang="es"> <head> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover" name="viewport"/> <meta content="yes" name="mobile-web-app-capable"/> <meta content="#ffffff" id="theme-color-light" media="(prefers-color-scheme: light)" name="theme-color"/> <meta content="#0f1419" id="theme-color-dark" media="(prefers-color-scheme: dark)" name="theme-color"/> <meta content="yes" name="apple-mobile-web-app-capable"/> <meta content="default" name="apple-mobile-web-app-status-bar-style"/> <script>
#     (function(){
#       var t='system';
#       try{t=localStorage.getItem('guiaoleo_theme')||'system'}catch(e){}
#       var isDark=t==='dark'||(t==='system'&&matchMedia('(prefers-color-scheme:dark)').matches);
#       if(isDark)document.documentElement.classList.add('dark');
#       // Update theme-color meta tags for browser chrome
#       var lightMeta=document.getElementById('theme-color-light');
#       var darkMeta=document.getElementById('theme-color-dark');
#       if(lightMeta)lightMeta.content=isDark?'#0f1419':'#ffffff';
#       if(darkMeta)darkMeta.content=isDark?'#0f1419':'#ffffff';
#     })();
#     </script> <title>Restaurantes en Buenos Aires | Guía Oleo</title> <meta content="¡Volvió! Descubre los mejores restaurantes con calificaciones reales de comensales reales. La guía gastronómica más democrática del país." name="description"/> <meta content="website" property="og:type"/> <meta content="https://guiaoleo.com/buenos-aires/restaurants" property="og:url"/> <meta content="Restaurantes en Buenos Aires | Guía Oleo" property="og:title"/> <meta content="¡Volvió! Descubre los mejores restaurantes con calificaciones reales de comensales reales. La guía gastronómica más democrática del país." property="og:description"/> <meta content="https://guiaoleo.com/assets/images/guiaoleo-og.jpg" property="og:image"/> <meta content="Guía Oleo" property="og:site_name"/> <meta content="es_AR" property="og:locale"/> <link href="https://guiaoleo.com/buenos-aires/restaurants" rel="canonical"/> <meta content="summary_large_image" property="twitter:card"/> <meta content="https://guiaoleo.com/buenos-aires/restaurants" property="twitter:url"/> <meta content="Restaurantes en Buenos Aires | Guía Oleo" property="twitter:title"/> <meta content="¡Volvió! Descubre los mejores restaurantes con calificaciones reales de comensales reales. La guía gastronómica más democrática del país." property="twitter:description"/> <meta content="https://guiaoleo.com/assets/images/guiaoleo-og.jpg" property="twitter:image"/> <meta content="@guiaoleo" property="twitter:site"/> <meta content="b5dcdcc0735af9f28de00002cc5acb5a93739189594f255ba2f11e5f5c46c56b" name="csrf-token"/> <meta content="AIzaSyAd_mosp2joMbVJutHlmUhDP4iWVA0x4KI" name="google-maps-api-key"/> <script defer="" src="/assets/js/constants.js?v=be2dadd6"></script> <script defer="" src="/assets/js/theme.js?v=be2dadd6"></script> <script defer="" src="/assets/js/utils/csrf.js?v=be2dadd6"></script> <script>document.addEventListener('DOMContentLoaded', function() { CsrfUtil.interceptForms(); });</script> <script defer="" src="/assets/js/utils/toast.js?v=be2dadd6"></script> <script defer="" src="/assets/js/utils/error-handler.js?v=be2dadd6"></script> <script defer="" src="/assets/js/utils/http.js?v=be2dadd6"></script> <script defer="" src="/assets/js/utils/focus-trap.js?v=be2dadd6"></script> <script defer="" src="/assets/js/utils/password-toggle.js?v=be2dadd6"></script> <script defer="" src="/assets/js/components/media-slideshow.js?v=be2dadd6"></script> <script defer="" src="/assets/js/components/video-hover-autoplay.js?v=be2dadd6"></script> <script defer="" src="/assets/js/components/truncatable-content.js?v=be2dadd6"></script> <script>
#     (function() {
#         var loaded = false;
#         function loadAnalytics() {
#             if (loaded) return;
#             loaded = true;
#
#             // Detect PWA standalone mode (installed app vs browser)
#             var isPwa = window.matchMedia('(display-mode: standalone)').matches || window.navigator.standalone === true;
#
#                         // Google Tag Manager
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#                 var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true; j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-MLKXHKF2');
#
#                         // PostHog
#             !function (t, e) { var o, n, p, r; e.__SV || (window.posthog = e, e._i = [], e.init = function (i, s, a) { function g(t, e) { var o = e.split("."); 2 == o.length && (t = t[o[0]], e = o[1]), t[e] = function () { t.push([e].concat(Array.prototype.slice.call(arguments, 0))) } } (p = t.createElement("script")).type = "text/javascript", p.crossOrigin = "anonymous", p.async = !0, p.src = s.api_host.replace(".i.posthog.com", "-assets.i.posthog.com") + "/static/array.js", (r = t.getElementsByTagName("script")[0]).parentNode.insertBefore(p, r); var u = e; for (void 0 !== a ? u = e[a] = [] : a = "posthog", u.people = u.people || [], u.toString = function (t) { var e = "posthog"; return "posthog" !== a && (e += "." + a), t || (e += " (stub)"), e }, u.people.toString = function () { return u.toString(1) + ".people (stub)" }, o = "init capture register register_once register_for_session unregister unregister_for_session getFeatureFlag getFeatureFlagPayload isFeatureEnabled reloadFeatureFlags updateEarlyAccessFeatureEnrollment getEarlyAccessFeatures on onFeatureFlags onSessionId getSurveys getActiveMatchingSurveys renderSurvey canRenderSurvey getNextSurveyStep identify setPersonProperties group resetGroups setPersonPropertiesForFlags resetPersonPropertiesForFlags setGroupPropertiesForFlags resetGroupPropertiesForFlags reset get_distinct_id getGroups get_session_id get_session_replay_url alias set_config startSessionRecording stopSessionRecording sessionRecordingStarted captureException loadToolbar get_property getSessionProperty createPersonProfile opt_in_capturing opt_out_capturing has_opted_in_capturing has_opted_out_capturing clear_opt_in_out_capturing debug".split(" "), n = 0; n < o.length; n++)g(u, o[n]); e._i.push([i, s, a]) }, e.__SV = 1) }(document, window.posthog || []);
#             posthog.init('phc_2skVOzll17DaeWmiyUg0Z7EVzQizxOAONmVk0Ha8QsE', {
#                 api_host: 'https://us.i.posthog.com',
#                 person_profiles: 'identified_only',
#                 capture_pageview: true,
#                 capture_pageleave: true
#             });
#                         posthog.register({ is_pwa: isPwa });
#
#             // PWA mode for GTM/GA4
#             window.dataLayer.push({ pwa_mode: isPwa ? 'standalone' : 'browser' });
#
#             // Meta Pixel
#             !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '1408383157441391');
#             fbq('track', 'PageView');
#         }
#
#         // Stub dataLayer so GTM calls before load don't error
#         window.dataLayer = window.dataLayer || [];
#
#         // Load on first user interaction or after 3.5s timeout
#         var events = ['scroll', 'click', 'touchstart', 'keydown'];
#         function onInteraction() {
#             events.forEach(function(e) { document.removeEventListener(e, onInteraction); });
#             loadAnalytics();
#         }
#         events.forEach(function(e) { document.addEventListener(e, onInteraction, {once: true, passive: true}); });
#         setTimeout(loadAnalytics, 3500);
#     })();
#     </script> <noscript><img height="1" src="https://www.facebook.com/tr?id=1408383157441391&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript> <link as="font" crossorigin="" href="/assets/fonts/inter-latin.woff2" rel="preload" type="font/woff2"/> <link href="/assets/css/fonts.css?v=be2dadd6" rel="stylesheet"/> <link href="/assets/css/tailwind.css?v=be2dadd6" rel="stylesheet"/> <link href="/assets/css/restaurant.css?v=be2dadd6" rel="stylesheet"/> <link href="/assets/css/levels.css?v=be2dadd6" media="print" onload="this.media='all'" rel="stylesheet"/> <noscript><link href="/assets/css/levels.css?v=be2dadd6" rel="stylesheet"/></noscript> <link href="/assets/css/footer-logo.css?v=be2dadd6" media="print" onload="this.media='all'" rel="stylesheet"/> <noscript><link href="/assets/css/footer-logo.css?v=be2dadd6" rel="stylesheet"/></noscript> <link href="https://maps.googleapis.com" rel="preconnect"/> <link crossorigin="" href="https://a.basemaps.cartocdn.com" rel="preconnect"/> <link href="/assets/favicon/apple-touch-icon-v2.png" rel="apple-touch-icon" sizes="180x180"/> <link href="/assets/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/> <link href="/assets/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/> <link href="/assets/favicon/site.webmanifest" rel="manifest"/> <link href="/assets/splash/splash-750x1334.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-dark-750x1334.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait) and (prefers-color-scheme: dark)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-828x1792.png" media="(device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-dark-828x1792.png" media="(device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait) and (prefers-color-scheme: dark)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-1125x2436.png" media="(device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-dark-1125x2436.png" media="(device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: dark)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-1170x2532.png" media="(device-width: 390px) and (device-height: 844px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-dark-1170x2532.png" media="(device-width: 390px) and (device-height: 844px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: dark)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-1179x2556.png" media="(device-width: 393px) and (device-height: 852px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-dark-1179x2556.png" media="(device-width: 393px) and (device-height: 852px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: dark)" rel="apple-touch-startup-image"/> <link href="/assets/splash/splash-1206x2622.png" media="(device-width: 402px) and (device-height: 874px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait) and (prefers-color-scheme: light)" rel="apple-touch-startup-image"/> <link href="/ass ...
#         body {
#             font-family: Inter, sans-serif;
#         }
#
#         /* Brand colors and rating bars now defined in input.css */
#
#
#         /* Prevent restaurant elements from disappearing */
#         .restaurant-rate-btn,
#         .amenity-item,
#         .amenity-dot {
#             visibility: visible !important;
#             opacity: 1 !important;
#             display: flex !important;
#         }
#
#         .amenity-dot {
#             display: inline-block !important;
#             min-width: 1rem;
#             min-height: 1rem;
#         }
#
#         /* Restaurant avatar colors - consistent with PHP function */
#         .restaurant-avatar {
#             transition: transform 0.2s ease-in-out;
#         }
#
#         .restaurant-avatar:hover {
#             transform: scale(1.05);
#         }
#
#         /* Ensure buttons don't fade out */
#         button[onclick],
#         a[href*="rate"],
#         .restaurant-rate-btn {
#             visibility: visible !important;
#             opacity: 1 !important;
#         }
#
#         /* Force visibility for amenities */
#         .amenity-item {
#             animation: none !important;
#             transition: none !important;
#         }
#
#         /* Navigation utilities */
#         .rotate-180 {
#             transform: rotate(180deg);
#         }
#
#         /* Prevent zoom on input focus in iOS */
#         input[type="text"],
#         input[type="email"],
#         input[type="password"],
#         input[type="number"],
#         input[type="tel"],
#         input[type="url"],
#         input[type="search"],
#         textarea,
#         select {
#             font-size: 16px !important;
#         }
#
#         @media screen and (max-width: 768px) {
#
#             input[type="text"],
#             input[type="email"],
#             input[type="password"],
#             input[type="number"],
#             input[type="tel"],
#             input[type="url"],
#             input[type="search"],
#             textarea,
#             select {
#                 font-size: 16px !important;
#             }
#         }
#
#         /* Toast Notification/Tooltip Styles */
#         @keyframes fadeInDown {
#             from {
#                 opacity: 0;
#                 transform: translate(-50%, -5px);
#             }
#
#             to {
#                 opacity: 1;
#                 transform: translate(-50%, 0);
#             }
#         }
#
#         .animate-fade-in-down {
#             animation: fadeInDown 0.2s ease-out forwards;
#         }
#     </style> </head> <body class="min-h-screen" style="background-color: var(--bg-page); color: var(--text-primary);"> <a class="sr-only focus:not-sr-only focus:absolute focus:top-4 focus:left-4 focus:z-[9999] focus:bg-white focus:px-4 focus:py-2 focus:rounded-lg focus:shadow-lg focus:text-primary focus:font-medium" href="#main-content">
# Ir al contenido principal
# </a> <div class="fixed top-0 left-0 right-0 z-[9999] pointer-events-none" id="ios-status-bar-bg" style="height: env(safe-area-inset-top, 0px); background-color: var(--bg-surface);"></div> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MLKXHKF2" style="display:none;visibility:hidden" width="0"></iframe></noscript> <div class="fixed left-0 right-0 shadow-lg p-4 z-[60] hidden transform -translate-y-full transition-transform duration-300" id="push-notification-banner" style="top: env(safe-area-inset-top, 0px); bottom: auto; background-color: var(--bg-surface); border-bottom: 1px solid var(--border-primary);"> <div class="max-w-7xl mx-auto flex items-center justify-between gap-4"> <div class="flex items-center gap-3 flex-1 min-w-0"> <div class="w-10 h-10 bg-oleo-green rounded-full flex items-center justify-center flex-shrink-0"> <svg class="w-5 h-5 text-white" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M15 17h5l-1.405-1.405A2.032 2.032 0 0118 14.158V11a6.002 6.002 0 00-4-5.659V5a2 2 0 10-4 0v.341C7.67 6.165 6 8.388 6 11v3.159c0 .538-.214 1.055-.595 1.436L4 17h5m6 0v1a3 3 0 11-6 0v-1m6 0H9" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"> </path> </svg> </div> <div class="min-w-0"> <p class="font-semibold text-gray-900 dark:text-gray-100 text-sm sm:text-base">Activar notificaciones</p> <p class="text-xs sm:text-sm text-gray-500 dark:text-gray-400 truncate">Enterate cuando alguien comente o te siga</p> </div> </div> <div class="flex items-center gap-2 flex-shrink-0"> <button aria-label="Cerrar" class="text-gray-400 dark:text-gray-500 hover:text-gray-600 dark:hover:text-gray-300 p-2" id="push-dismiss"> <svg class="w-5 h-5" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M6 18L18 6M6 6l12 12" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"> </path> </svg> </button> <button class="bg-oleo-green text-white px-4 py-2 rounded-lg text-sm font-medium hover:bg-green-800 transition-colors" id="push-enable-btn">
# Activar
# </button> </div> </div> </div> <nav class="shadow-sm z-50 transition-colors duration-300 sticky top-0" style="padding-top: env(safe-area-inset-top, 0px); background-color: var(--bg-surface); border-bottom: 1px solid var(--border-primary);"> <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8"> <div class="hidden lg:flex justify-between items-center h-16"> <div class="flex items-center"> <div class="relative flex items-center" onmouseenter="openCityDropdownOnHover()" onmouseleave="closeCityDropdownOnHover()"> <a class="flex items-center space-x-3 group" href="https://guiaoleo.com/"> <picture> <source srcset="/assets/logos/guia-oleo-logo.webp" type="image/webp"/> <img alt="Guía Oleo" class="h-8 w-auto transition-transform duration-300 ease-out group-hover:scale-110" height="192" src="/assets/logos/guia-oleo-logo.png" width="192"/> </picture> </a> <a class="city-link ml-3" href="https://guiaoleo.com/buenos-aires"> <span class="city-name font-bold text-lg text-gray-900 dark:text-gray-100 border-b-2 border-transparent hover:border-gray-900 dark:hover:border-gray-100 transition-colors">Buenos Aires</span> </a> <button aria-expanded="false" aria-haspopup="true" aria-label="Cambiar ciudad" class="ml-1 p-1 rounded hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" id="city-dropdown-btn" onclick="toggleCityDropdown()" type="button"> <svg aria-hidden="true" class="w-4 h-4 transition-transform duration-200 text-gray-500 dark:text-gray-400" fill="none" id="city-dropdown-arrow" stroke="currentColor" viewbox="0 0 24 24"> <path d="M19 9l-7 7-7-7" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"> </path> </svg> </button> <div aria-label="Ciudades disponibles" class="hidden absolute top-full left-0 mt-1 w-56 rounded-lg shadow-lg z-[100]" id="city-dropdown" onmouseenter="openCityDropdownOnHover()" onmouseleave="closeCityDropdownOnHover()" role="menu" style="background-color: var(--bg-surface); border: 1px solid var(--border-primary);"> <div class="p-2 border-b border-gray-100 dark:border-gray-700"> <input autocomplete="off" class="w-full px-3 py-1.5 text-sm bg-gray-50 dark:bg-gray-700 border border-gray-200 dark:border-gray-600 rounded-md focus:ring-1 focus:ring-primary focus:border-primary text-gray-900 dark:text-gray-100 placeholder-gray-400 dark:placeholder-gray-500 outline-none" id="city-search-input" placeholder="Buscar ciudad..." type="text"/> </div> <div class="py-1" id="city-default-list"> <div class="px-3 py-2 text-xs font-semibold text-gray-500 dark:text-gray-400 uppercase tracking-wide border-b border-gray-100 dark:border-gray-700">
# Elegir ciudad
# </div> <a class="block px-3 py-2 text-sm transition-colors bg-green-50 dark:bg-green-900/30 font-medium text-primary" href="https://guiaoleo.com/buenos-aires" onclick="selectCity('buenos-aires', 'Buenos Aires'); return false;"> <div class="flex items-center justify-between"> <span>Buenos Aires</span> <svg class="w-4 h-4" fill="currentColor" viewbox="0 0 20 20"> <path clip-rule="evenodd" d="M16.707 5.293a1 1 0 010 1.414l-8 8a1 1 0 01-1.414 0l-4-4a1 1 0 011.414-1.414L8 12.586l7.293-7.293a1 1 0 011.414 0z" fill-rule="evenodd"></path> </svg> </div> </a> <a class="block px-3 py-2 text-sm transition-colors text-gray-700 dark:text-gray-300 hover:bg-gray-50 dark:hover:bg-green-900/20 hover:text-primary" href="https://guiaoleo.com/mar-del-plata" onclick="selectCity('mar-del-plata', 'Mar del Plata'); return false;"> <div class="flex items-center justify-between"> <span>Mar del Plata</span> </div> </a> <div class="px-3 py-2 text-xs font-semibold text-gray-500 dark:text-gray-400 uppercase tracking-wide border-t border-gray-100 dark:border-gray-700 mt-1">
# Creciendo
# </div> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-50 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/rosario"> <div class="flex items-center justify-between"> <span>Rosario</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-50 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/quilmes"> <div class="flex items-center justify-between"> <span>Quilmes</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-50 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/pilar"> <div class="flex items-center justify-between"> <span>Pilar</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> </div> <div class="hidden py-1 max-h-48 overflow-y-auto" id="city-search-results"></div> </div> </div> </div> <div class="flex-1 max-w-md mx-4"> <form action="https://guiaoleo.com/search" class="relative" method="GET" onsubmit="return false;" role="search"> <label class="sr-only" for="search-input-desktop">Buscar restaurantes y usuarios</label> <input autocomplete="off" class="w-full pl-10 pr-4 py-2 bg-gray-100 dark:bg-gray-800 border border-gray-300 dark:border-gray-600 rounded-lg focus:bg-white dark:focus:bg-gray-700 focus:ring-2 focus:ring-gray-300 dark:focus:ring-gray-600 focus:border-gray-400 dark:focus:border-gray-500 text-sm text-gray-900 dark:text-gray-100 placeholder-gray-500 dark:placeholder-gray-400 transition-all outline-none" id="search-input-desktop" name="q" placeholder="Buscar restaurantes, usuarios..." type="text" value=""/> <div class="absolute inset-y-0 left-0 pl-3 flex items-center pointer-events-none"> <svg aria-hidden="true" class="h-4 w-4 text-gray-500 dark:text-gray-400" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M21 21l-6-6m2-5a7 7 0 11-14 0 7 7 0 0114 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </div> </form> </div> <div class="flex items-center space-x-2"> <button aria-label="Cambiar tema" class="p-2 rounded-lg hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" data-theme-toggle="" onclick="ThemeManager.cycleTheme()" type="button"> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400" data-icon="sun" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M12 3v1m0 16v1m9-9h-1M4 12H3m15.364 6.364l-.707-.707M6.343 6.343l-.707-.707m12.728 0l-.707.707M6.343 17.657l-.707.707M16 12a4 4 0 11-8 0 4 4 0 018 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400 hidden" data-icon="moon" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M20.354 15.354A9 9 0 018.646 3.646 9.003 9.003 0 0012 21a9.003 9.003 0 008.354-5.646z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400 hidden" data-icon="system" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M9.75 17L9 20l-1 1h8l-1-1-.75-3M3 13h18M5 17h14a2 2 0 002-2V5a2 2 0 00-2-2H5a2 2 0 00-2 2v10a2 2 0 002 2z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </button> <button class="text-gray-700 dark:text-gray-300 px-4 py-2 rounded-lg text-sm font-medium transition-colors border border-gray-300 dark:border-gray-600 hover:bg-gray-100 dark:hover:bg-gray-700 cursor-pointer" onclick="showLoginModal()" type="button">
# Ingresar
# </button> <button class="text-primary bg-white dark:bg-gray-800 px-4 py-2 rounded-lg text-sm font-bold border border-gray-300 dark:border-gray-600 transition-colors hover:bg-gray-100 dark:hover:bg-gray-700 cursor-pointer" onclick="showRegisterModal()" type="button">
# Registrarse
# </button> </div> </div> <div class="flex lg:hidden justify-between items-center h-16"> <div class="flex items-center flex-1 min-w-0"> <div class="relative flex items-center min-w-0"> <a class="flex-shrink-0 flex items-center space-x-2 group" href="https://guiaoleo.com/"> <picture> <source srcset="/assets/logos/guia-oleo-logo.webp" type="image/webp"/> <img alt="Guía Oleo" class="h-8 w-auto transition-transform duration-300 ease-out group-hover:scale-110" height="192" src="/assets/logos/guia-oleo-logo.png" width="192"/> </picture> </a> <a class="city-link ml-2 truncate" href="https://guiaoleo.com/buenos-aires"> <span class="mobile-city-name font-bold text-base text-gray-900 dark:text-gray-100 border-b-2 border-transparent hover:border-gray-900 dark:hover:border-gray-100">Buenos Aires</span> </a> <button aria-expanded="false" aria-haspopup="true" aria-label="Cambiar ciudad" class="ml-1 p-1 rounded hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" id="mobile-city-dropdown-btn" onclick="toggleMobileCityDropdown()" type="button"> <svg aria-hidden="true" class="w-3 h-3 transition-transform duration-200 text-gray-500 dark:text-gray-400" fill="none" id="mobile-city-dropdown-arrow" stroke="currentColor" viewbox="0 0 24 24"> <path d="M19 9l-7 7-7-7" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"> </path> </svg> </button> <div aria-label="Ciudades disponibles" class="hidden fixed left-0 right-0 w-full backdrop-blur-md shadow-lg z-[100]" id="mobile-city-dropdown" role="menu" style="top: calc(4rem + env(safe-area-inset-top, 0px)); background-color: var(--bg-surface); border-bottom: 1px solid var(--border-primary);"> <div class="p-2 border-b border-gray-200 dark:border-gray-700"> <input autocomplete="off" class="w-full px-3 py-2 text-sm bg-gray-50 dark:bg-gray-700 border border-gray-200 dark:border-gray-600 rounded-md focus:ring-1 focus:ring-primary focus:border-primary text-gray-900 dark:text-gray-100 placeholder-gray-400 dark:placeholder-gray-500 outline-none" id="mobile-city-search-input" placeholder="Buscar ciudad..." type="text"/> </div> <div class="py-1" id="mobile-city-default-list"> <div class="px-3 py-2 text-xs font-semibold text-gray-500 dark:text-gray-400 uppercase tracking-wide border-b border-gray-200 dark:border-gray-700">
# Elegir ciudad
# </div> <a class="block px-3 py-2 text-sm text-gray-600 dark:text-gray-300 hover:bg-gray-100 dark:hover:bg-green-900/20 hover:text-primary transition-colors bg-gray-100 dark:bg-gray-700 font-medium text-gray-900 dark:text-gray-100" href="https://guiaoleo.com/buenos-aires" onclick="selectCity('buenos-aires', 'Buenos Aires'); return false;"> <div class="flex items-center justify-between"> <span>Buenos Aires</span> <svg class="w-4 h-4 fill-primary" viewbox="0 0 20 20"> <path clip-rule="evenodd" d="M16.707 5.293a1 1 0 010 1.414l-8 8a1 1 0 01-1.414 0l-4-4a1 1 0 011.414-1.414L8 12.586l7.293-7.293a1 1 0 011.414 0z" fill-rule="evenodd"></path> </svg> </div> </a> <a class="block px-3 py-2 text-sm text-gray-600 dark:text-gray-300 hover:bg-gray-100 dark:hover:bg-green-900/20 hover:text-primary transition-colors" href="https://guiaoleo.com/mar-del-plata" onclick="selectCity('mar-del-plata', 'Mar del Plata'); return false;"> <div class="flex items-center justify-between"> <span>Mar del Plata</span> </div> </a> <div class="px-3 py-2 text-xs font-semibold text-gray-500 dark:text-gray-400 uppercase tracking-wide border-t border-gray-200 dark:border-gray-700 mt-1">
# Creciendo
# </div> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/rosario"> <div class="flex items-center justify-between"> <span>Rosario</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/quilmes"> <div class="flex items-center justify-between"> <span>Quilmes</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> <a class="block px-3 py-2 text-sm text-gray-500 dark:text-gray-400 hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" href="https://guiaoleo.com/pilar"> <div class="flex items-center justify-between"> <span>Pilar</span> <span class="inline-block px-1.5 py-0.5 rounded text-[10px] font-medium bg-amber-50 dark:bg-amber-900/30 text-amber-600 dark:text-amber-400">Creciendo</span> </div> </a> </div> <div class="hidden py-1 max-h-60 overflow-y-auto" id="mobile-city-search-results"></div> </div> </div> </div> <div class="flex items-center space-x-1 h-16 flex-shrink-0"> <button class="text-sm font-medium text-gray-700 dark:text-gray-300 transition-colors hover:text-gray-900 dark:hover:text-gray-100 cursor-pointer" onclick="showLoginModal()" type="button">
# Ingresar
# </button> <button aria-label="Cambiar tema" class="p-2 rounded-lg hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" data-theme-toggle="" onclick="ThemeManager.cycleTheme()" type="button"> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400" data-icon="sun" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M12 3v1m0 16v1m9-9h-1M4 12H3m15.364 6.364l-.707-.707M6.343 6.343l-.707-.707m12.728 0l-.707.707M6.343 17.657l-.707.707M16 12a4 4 0 11-8 0 4 4 0 018 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400 hidden" data-icon="moon" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M20.354 15.354A9 9 0 018.646 3.646 9.003 9.003 0 0012 21a9.003 9.003 0 008.354-5.646z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400 hidden" data-icon="system" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M9.75 17L9 20l-1 1h8l-1-1-.75-3M3 13h18M5 17h14a2 2 0 002-2V5a2 2 0 00-2-2H5a2 2 0 00-2 2v10a2 2 0 002 2z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </button> <button aria-label="Buscar" class="p-2 rounded-lg hover:bg-gray-100 dark:hover:bg-gray-700 transition-colors" id="mobile-search-btn-guest" onclick="toggleMobileSearch()" type="button"> <svg aria-hidden="true" class="w-5 h-5 text-gray-600 dark:text-gray-400" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M21 21l-6-6m2-5a7 7 0 11-14 0 7 7 0 0114 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </button> </div> </div> <div class="hidden lg:hidden shadow-sm z-50" id="mobile-notification-menu" style="background-color: var(--bg-surface); border-top: 1px solid var(--border-primary);"> <div class="px-4 py-3"> <div class="flex items-center justify-between mb-3"> <h3 class="font-semibold text-gray-900 dark:text-gray-100">Notificaciones</h3> <div class="hidden" id="mobile-push-toggle-container"> <button aria-checked="false" class="relative inline-flex h-6 w-11 items-center rounded-full transition-colors focus:outline-none bg-gray-200 dark:bg-gray-600" id="mobile-push-toggle-btn" onclick="togglePushNotifications()" role="switch" title="Notificaciones push"> <span class="inline-block h-5 w-5 transform rounded-full bg-white shadow transition-transform translate-x-0.5" id="mobile-push-toggle-dot"></span> </button> </div> </div> <div class="max-h-96 overflow-y-auto"> <div class="divide-y divide-gray-100 dark:divide-gray-700" id="mobile-notification-list"> <div class="p-8 text-center text-gray-500 dark:text-gray-400"> <svg class="w-12 h-12 mx-auto mb-2 text-gray-400 dark:text-gray-500" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M15 17h5l-1.405-1.405A2.032 2.032 0 0118 14.158V11a6.002 6.002 0 00-4-5.659V4a2 2 0 10-4 0v1.341C7.67 6.165 6 8.388 6 11v3.159c0 .538-.214 1.055-.595 1.436L4 17h5m6 0v1a3 3 0 11-6 0v-1m6 0H9" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"> </path> </svg> <p class="text-sm">Cargando notificaciones...</p> </div> </div> </div> <div class="mt-4 pt-3 border-t border-gray-200 dark:border-gray-700 flex items-center justify-between"> <button class="text-sm text-gray-500 dark:text-gray-400 hover:text-gray-700 dark:hover:text-gray-200" onclick="markAllNotificationsRead()">
# Marcar como leídas
# </button> <a class="text-sm text-primary hover:text-primary-dark font-medium" href="/notifications">
# Ver todas
# </a> </div> </div> </div> <div class="hidden lg:hidden backdrop-blur-md shadow-sm relative z-50" id="mobile-menu" style="background-color: var(--bg-surface); border-top: 1px solid var(--border-primary);"> <div class="px-4 py-3"> <form action="https://guiaoleo.com/search" class="relative" method="GET" role="search"> <label class="sr-only" for="search-input-mobile">Buscar restaurantes y usuarios</label> <input class="w-full pl-10 pr-4 py-3 bg-gray-100 dark:bg-gray-800 border border-gray-300 dark:border-gray-600 rounded-lg focus:ring-2 focus:ring-gray-300 dark:focus:ring-gray-600 text-sm text-gray-900 dark:text-gray-100 placeholder-gray-500 dark:placeholder-gray-400 outline-none" id="search-input-mobile" name="q" placeholder="Buscar restaurantes, usuarios..." type="text" value=""/> <div class="absolute inset-y-0 left-0 pl-3 flex items-center pointer-events-none"> <svg aria-hidden="true" class="w-5 h-5 text-gray-500" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M21 21l-6-6m2-5a7 7 0 11-14 0 7 7 0 0114 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </div> </form> </div> </div> <div class="hidden lg:hidden backdrop-blur-md shadow-sm relative z-50" id="mobile-menu-guest" style="background-color: var(--bg-surface); border-top: 1px solid var(--border-primary);"> <div class="px-4 py-3"> <form action="https://guiaoleo.com/search" class="relative" method="GET" role="search"> <label class="sr-only" for="search-input-mobile-guest">Buscar restaurantes y usuarios</label> <input autocomplete="off" class="w-full pl-10 pr-4 py-3 bg-gray-100 dark:bg-gray-800 border border-gray-300 dark:border-gray-600 rounded-lg focus:ring-2 focus:ring-gray-300 dark:focus:ring-gray-600 text-sm text-gray-900 dark:text-gray-100 placeholder-gray-500 dark:placeholder-gray-400 outline-none" data-mobile="true" id="search-input-mobile-guest" name="q" placeholder="Buscar restaurantes, usuarios..." type="text"/> <div class="absolute inset-y-0 left-0 pl-3 flex items-center pointer-events-none"> <svg aria-hidden="true" class="h-5 w-5 text-gray-500" fill="none" stroke="currentColor" viewbox="0 0 24 24"> <path d="M21 21l-6-6m2-5a7 7 0 11-14 0 7 7 0 0114 0z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path> </svg> </div> </form> </div> </div> </div> </nav> <div class="fixed inset-0 bg-black/50 dark:bg-black/70 z-40 hidden lg:hidden" id="mobile-dropdown-overlay" onclick="closeMobileDropdowns()" style="top: calc(4rem + env(safe-area-inset-top, 0px));"></div> <script>
#     (function () {
#         'use strict';
#
#         // Mobile Dropdown Overlay with scroll lock (iOS compatible)
#         let scrollPosition = 0;
#
#         function showMobileOverlay() {
#             document.getElementById('mobile-dropdown-overlay')?.classList.remove('hidden');
#             // Lock scroll (iOS compatible)
#             scrollPosition = window.pageYOffset;
#             document.body.style.position = 'fixed';
#             document.body.style.top = `-${scrollPosition}px`;
#             document.body.style.width = '100%';
#         }
#
#         function hideMobileOverlay() {
#             document.getElementById('mobile-dropdown-overlay')?.classList.add('hidden');
#             // Restore scroll
#             document.body.style.position = '';
#             document.body.style.top = '';
#             document.body.style.width = '';
#             window.scrollTo(0, scrollPosition);
#         }
#
#         function closeMobileDropdowns() {
#             document.getElementById('mobile-user-dropdown')?.classList.add('hidden');
#             document.getElementById('mobile-notification-menu')?.classList.add('hidden');
#             document.getElementById('mobile-menu')?.classList.add('hidden');
#             document.getElementById('mobile-menu-guest')?.classList.add('hidden');
#             document.getElementById('mobile-city-dropdown')?.classList.add('hidden');
#             document.getElementById('mobile-city-dropdown-arrow')?.classList.remove('rotate-180');
#             resetCitySearch('mobile-');
#             hideMobileOverlay();
#         }
#
#         window.closeMobileDropdowns = closeMobileDropdowns;
#
#         // City Dropdown
#         function resetCitySearch(prefix) {
#             const input = document.getElementById(prefix + 'city-search-input');
#             if (input) input.value = '';
#             document.getElementById(prefix + 'city-default-list')?.classList.remove('hidden');
#             document.getElementById(prefix + 'city-search-results')?.classList.add('hidden');
#         }
#
#         function toggleCityDropdown() {
#             const dropdown = document.getElementById('city-dropdown');
#             const arrow = document.getElementById('city-dropdown-arrow');
#             dropdown.classList.toggle('hidden');
#             arrow.classList.toggle('rotate-180');
#             if (dropdown.classList.contains('hidden')) {
#                 resetCitySearch('');
#             }
#         }
#
#         // Main Menu (replaces user dropdown)
#         function toggleMainMenu() {
#             const dropdown = document.getElementById('main-menu');
#             dropdown.classList.toggle('hidden');
#         }
#
#         // Mobile Search
#         function toggleMobileSearch() {
#             // Try authenticated user menu first, then guest menu
#             const menu = document.getElementById('mobile-menu') || document.getElementById('mobile-menu-guest');
#             if (menu) {
#                 const wasHidden = menu.classList.contains('hidden');
#                 menu.classList.toggle('hidden');
#
#                 // Focus on search input when opening
#                 if (wasHidden && !menu.classList.contains('hidden')) {
#                     const searchInput = menu.querySelector('input[name="q"]');
#                     if (searchInput) {
#                         // Clear any previous value for fresh search
#                         searchInput.value = '';
#
#                         // Multiple attempts to focus and open keyboard
#                         const attemptFocus = () => {
#                             searchInput.focus();
#
#                             // Force focus with click event simulation
#                             const clickEvent = new Event('click', { bubbles: true });
#                             searchInput.dispatchEvent(clickEvent);
#
#                             // For touch devices, also trigger touch events
#                             if ('ontouchstart' in window) {
#                                 const touchEvent = new Event('touchstart', { bubbles: true });
#                                 searchInput.dispatchEvent(touchEvent);
#                             }
#
#                             // Set cursor at end of input
#                             searchInput.setSelectionRange(0, 0);
#                         };
#
#                         // Try immediately
#                         attemptFocus();
#
#                         // Try again after a small delay
#                         setTimeout(attemptFocus, 50);
#
#                         // Final attempt after menu is fully visible
#                         setTimeout(attemptFocus, 150);
#                     }
#                 }
#             }
#         }
#
#         // Mobile City Dropdown
#         function toggleMobileCityDropdown() {
#             const dropdown = document.getElementById('mobile-city-dropdown');
#             const arrow = document.getElementById('mobile-city-dropdown-arrow');
#             const isHidden = dropdown.classList.contains('hidden');
#             if (isHidden) {
#                 dropdown.classList.remove('hidden');
#                 arrow?.classList.add('rotate-180');
#                 showMobileOverlay();
#             } else {
#                 dropdown.classList.add('hidden');
#                 arrow?.classList.remove('rotate-180');
#                 resetCitySearch('mobile-');
#                 hideMobileOverlay();
#             }
#         }
#
#         // Mobile User Dropdown
#         function toggleMobileUserDropdown() {
#             const dropdown = document.getElementById('mobile-user-dropdown');
#             const isHidden = dropdown.classList.contains('hidden');
#
#             // Close other dropdowns first
#             document.getElementById('mobile-notification-menu')?.classList.add('hidden');
#             document.getElementById('mobile-menu')?.classList.add('hidden');
#             document.getElementById('mobile-menu-guest')?.classList.add('hidden');
#
#             if (isHidden) {
#                 dropdown.classList.remove('hidden');
#                 showMobileOverlay();
#             } else {
#                 dropdown.classList.add('hidden');
#                 hideMobileOverlay();
#             }
#         }
#
#         // Hamburger Menu (same as mobile menu for now)
#         function toggleHamburgerMenu() {
#             toggleMobileMenu();
#         }
#
#         // Bookmarks functionality
#         function openBookmarks() {
#                             if (typeof showLoginModal === 'function') showLoginModal();
#                     }
#
#         // Show invitations modal
#         function showInvitationsModal() {
#             // Close any open dropdowns first
#             document.getElementById('main-menu')?.classList.add('hidden');
#             document.getElementById('mobile-user-dropdown')?.classList.add('hidden');
#
#             // Fetch user invitation data
#             fetch('/api/user/invitations', {
#                 method: 'GET',
#                 headers: {
#                     'Accept': 'application/json',
#                     'X-CSRF-Token': document.querySelector('meta[name="csrf-token"]')?.getAttribute('content') || ''
#                 }
#             })
#                 .then(response => response.json())
#                 .then(data => {
#                     if (data.success) {
#                         showInvitationsPopup(data.data);
#                     } else {
#                         showToast(data.message || 'Error al cargar invitaciones', 'error');
#                     }
#                 })
#                 .catch(error => {
#                     console.error('Error:', error);
#                     // Fallback: redirect to profile
#                                             window.location.href = '/login';
#                                     });
#         }
#
#         function showInvitationsPopup(invitationData) {
#             const modal = document.getElementById('invitations-modal');
#             if (!modal) {
#                 createInvitationsModal(invitationData);
#             } else {
#                 updateInvitationsModalContent(invitationData);
#                 modal.classList.remove('hidden');
#             }
#         }
#
#         function createInvitationsModal(invitationData) {
#             const modalHTML = `
#             <div id="invitations-modal" class="fixed inset-0 bg-black/50 overflow-y-auto h-full w-full z-50 flex items-center justify-center p-4">
#                 <div class="relative mx-auto max-w-md w-full bg-white dark:bg-gray-800 rounded-xl shadow-xl border border-gray-200 dark:border-gray-700">
#                     <div class="p-6">
#                         <button onclick="closeInvitationsModal()" class="absolute top-4 right-4 text-gray-400 hover:text-gray-600 dark:hover:text-gray-300 transition-colors">
#                             <svg class="w-5 h-5" fill="none" stroke="currentColor" viewBox="0 0 24 24">
#                                 <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M6 18L18 6M6 6l12 12"></path>
#                             </svg>
#                         </button>
#                         <div id="invitations-content">
#                             ${generateInvitationsContent(invitationData)}
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         `;
#             document.body.insertAdjacentHTML('beforeend', modalHTML);
#
#             // Add click outside to close
#             document.getElementById('invitations-modal').addEventListener('click', function (e) {
#                 if (e.target === this) {
#                     closeInvitationsModal();
#                 }
#             });
#         }
#
#         function generateInvitationsContent(data) {
#             const firstCode = data.userCodes && data.userCodes.length > 0 ? data.userCodes[0] : null;
#
#             if (!firstCode) {
#                 return `
#                 <div class="text-center py-6">
#                     <p class="text-gray-600 dark:text-gray-300 font-medium mb-1">Error al cargar tu codigo de invitacion</p>
#                 </div>
#                 `;
#             }
#
#             const inviteUrl = window.location.origin + '/register?invite=' + firstCode.code;
#
#             let html = `
#                 <div class="text-center mb-5">
#                     <h3 class="text-xl font-semibold text-gray-900 dark:text-gray-100 mb-1">Invita a tus amigos</h3>
#                     <p class="text-gray-500 dark:text-gray-400">Quienes se registren te van a seguir automaticamente</p>
#                 </div>
#
#                 <div class="text-center mb-5">
#                     <p class="text-sm text-gray-500 dark:text-gray-400 mb-1">Codigo de invitacion</p>
#                     <p class="text-2xl font-bold tracking-wider text-gray-900 dark:text-gray-100">${firstCode.code}</p>
#                     <input type="text" value="${inviteUrl}" readonly class="sr-only" id="modal-invite-url-main">
#                 </div>
#
#                 <div class="flex gap-2 mb-6">
#                     <button
#                         onclick="copyModalInviteLink('main')"
#                         class="flex-1 px-3 py-2.5 bg-oleo-green text-white rounded-lg hover:bg-green-800 transition-colors flex items-center justify-center gap-2 font-medium cursor-pointer"
#                         id="copy-invite-btn"
#                     >
#                         <svg class="w-4 h-4" fill="none" stroke="currentColor" viewBox="0 0 24 24">
#                             <path stroke-linecap="round" stroke-linejoin="round" stroke-width="2" d="M8 16H6a2 2 0 01-2-2V6a2 2 0 012-2h8a2 2 0 012 2v2m-6 12h8a2 2 0 002-2v-8a2 2 0 00-2-2h-8a2 2 0 00-2 2v8a2 2 0 002 2z"></path>
#                         </svg>
#                         Copiar
#                     </button>
#                     <button
#                         onclick="shareInviteWhatsApp('${inviteUrl}')"
#                         class="flex-1 px-3 py-2.5 bg-[#25D366] text-white rounded-lg hover:bg-[#1da851] transition-colors flex items-center justify-center gap-2 font-medium cursor-pointer"
#                     >
# ...
#                     menu.classList.add('hidden');
#                     resetDropdownPosition(menu);
#                 });
#             }
#         });
#
#         // Copy to clipboard utility
#         window.copyToClipboard = function (text, btnElement) {
#             if (navigator.clipboard) {
#                 navigator.clipboard.writeText(text).then(() => {
#                     showCopyTooltip(btnElement, '¡Enlace copiado!');
#                 }).catch(err => {
#                     console.error('Error al copiar: ', err);
#                     fallbackCopyTextToClipboard(text, btnElement);
#                 });
#             } else {
#                 fallbackCopyTextToClipboard(text, btnElement);
#             }
#         };
#
#         function fallbackCopyTextToClipboard(text, btnElement) {
#             var textArea = document.createElement("textarea");
#             textArea.value = text;
#             textArea.style.position = "fixed";  // Avoid scrolling to bottom
#             document.body.appendChild(textArea);
#             textArea.focus();
#             textArea.select();
#
#             try {
#                 var successful = document.execCommand('copy');
#                 if (successful) {
#                     showCopyTooltip(btnElement, '¡Enlace copiado!');
#                 } else {
#                     showCopyTooltip(btnElement, 'No se pudo copiar');
#                 }
#             } catch (err) {
#                 console.error('Fallback: Oops, unable to copy', err);
#                 showCopyTooltip(btnElement, 'No se pudo copiar');
#             }
#
#             document.body.removeChild(textArea);
#         }
#
#         function showCopyTooltip(element, message) {
#             // Create a small tooltip ABOVE the button
#             const toast = document.createElement('div');
#             toast.className = 'absolute bottom-full left-1/2 transform -translate-x-1/2 mb-2 px-2 py-1 bg-gray-800 text-white text-xs rounded shadow-lg whitespace-nowrap z-50 animate-fade-in-down';
#             toast.textContent = message;
#
#             // Add arrow pointing DOWN
#             const arrow = document.createElement('div');
#             arrow.className = 'absolute top-full left-1/2 transform -translate-x-1/2 border-4 border-transparent border-t-gray-800';
#             toast.appendChild(arrow);
#
#             // Ensure the parent has relative positioning for the absolute toast
#             if (window.getComputedStyle(element).position === 'static') {
#                 element.style.position = 'relative';
#             }
#
#             element.appendChild(toast);
#
#             // Remove after 2 seconds
#             setTimeout(() => {
#                 toast.classList.add('opacity-0', 'transition-opacity', 'duration-300');
#                 setTimeout(() => {
#                     if (toast.parentNode) {
#                         toast.parentNode.removeChild(toast);
#                     }
#                 }, 300);
#             }, 2000);
#         }
#     </script> <script>
#         (function() {
#             if ('serviceWorker' in navigator) {
#                 var hadController = !!navigator.serviceWorker.controller;
#                 var refreshing = false;
#                 navigator.serviceWorker.register('/sw.js').catch(function() {});
#                 navigator.serviceWorker.addEventListener('controllerchange', function() {
#                     if (!hadController || refreshing) return;
#                     refreshing = true;
#                     window.location.reload();
#                 });
#             }
#         })();
#     </script> <script>
#         document.addEventListener('DOMContentLoaded', function() {
#             const STORAGE_KEY = APP_CONSTANTS.STORAGE.REMEMBER_TOKEN;
#             const isAuthenticated = document.querySelector('meta[name="user-authenticated"]')?.content === 'true';
#
#
#             // If not authenticated but we have a localStorage token, try to restore session
#             if (!isAuthenticated) {
#                 try {
#                     const storedToken = localStorage.getItem(STORAGE_KEY);
#                     if (storedToken) {
#                         // Call API to restore session
#                         fetch('/api/auth/restore-session', {
#                             method: 'POST',
#                             headers: {
#                                 'Content-Type': 'application/json'
#                             },
#                             body: JSON.stringify({ token: storedToken })
#                         })
#                         .then(response => response.json())
#                         .then(data => {
#                             if (data.success && data.authenticated) {
#                                 // Session restored - update token if a new one was provided
#                                 if (data.new_token) {
#                                     localStorage.setItem(STORAGE_KEY, data.new_token);
#                                 }
#                                 // Reload page to show authenticated state
#                                 window.location.reload();
#                             } else if (data.clear_token) {
#                                 // Token is invalid, clear it
#                                 localStorage.removeItem(STORAGE_KEY);
#                             }
#                         })
#                         .catch(err => {
#                             console.warn('Could not restore session from localStorage:', err);
#                         });
#                     }
#                 } catch (e) {
#                     console.warn('Could not check localStorage for remember token:', e);
#                 }
#             }
#
#             // Expose function to clear token (used on logout)
#             window.clearRememberToken = function() {
#                 try {
#                     localStorage.removeItem(STORAGE_KEY);
#                 } catch (e) {
#                     console.warn('Could not clear remember token from localStorage:', e);
#                 }
#             };
#         });
#     </script> <script async="" defer="" src="https://accounts.google.com/gsi/client"></script> <script>
#         window.addEventListener('load', function() {
#             // Skip One Tap in Safari (shows generic UI due to privacy restrictions)
#             var isSafari = /^((?!chrome|android).)*safari/i.test(navigator.userAgent);
#             if (isSafari) return;
#
#             if (typeof google !== 'undefined' && google.accounts) {
#                 // After logout, disable auto-select so Google doesn't log the user back in
#                 var justLoggedOut = sessionStorage.getItem('guiaoleo_disable_autologin');
#                 if (justLoggedOut) {
#                     sessionStorage.removeItem('guiaoleo_disable_autologin');
#                     google.accounts.id.disableAutoSelect();
#                 }
#
#                 google.accounts.id.initialize({
#                     client_id: '441753289528-hf76kk6bdcjdavqa7qi30u0994t018o3.apps.googleusercontent.com',
#                     callback: handleGoogleOneTap,
#                     auto_select: !justLoggedOut,
#                     cancel_on_tap_outside: false,
#                     log_level: 'none'
#                 });
#                 google.accounts.id.prompt();
#             }
#         });
#
#         function handleGoogleOneTap(response) {
#             fetch(API_ENDPOINTS.GOOGLE_ONE_TAP, {
#                 method: 'POST',
#                 headers: {
#                     'Content-Type': 'application/x-www-form-urlencoded',
#                 },
#                 body: 'credential=' + encodeURIComponent(response.credential)
#             })
#             .then(res => res.json())
#             .then(data => {
#                 if (data.success && data.waitlist) {
#                     // New user without invite — show waitlist modal
#                     var msgEl = document.getElementById('waitlist-success-message');
#                     if (msgEl && data.message) msgEl.textContent = data.message;
#                     openAuthPanel('auth-waitlist-success');
#                 } else if (data.success && data.redirect) {
#                     if (data.message) {
#                         sessionStorage.setItem(APP_CONSTANTS.STORAGE.FLASH_SUCCESS, data.message);
#                     }
#                     window.location.href = data.redirect;
#                 } else if (data.error) {
#                     console.error('One Tap error:', data.error);
#                 }
#             })
#             .catch(err => {
#                 console.error('One Tap fetch error:', err);
#             });
#         }
#     </script> <script>
#         (function() {
#             var storageKey = (typeof APP_CONSTANTS !== 'undefined') ? APP_CONSTANTS.STORAGE.FLASH_SUCCESS : 'guiaoleo_flash_success';
#             var flashSuccess = sessionStorage.getItem(storageKey);
#             if (flashSuccess) {
#                 sessionStorage.removeItem(storageKey);
#                 if (typeof ToastUtil !== 'undefined') {
#                     ToastUtil.success(flashSuccess);
#                 }
#             }
#         })();
#     </script> <script>
# /**
#  * Shared unfollow confirmation modal + follow/unfollow logic.
#  * Used by: suggested-profiles, feed-follow-suggestions, restaurant-interactors, user-profile-card
#  */
#
# // --- Unfollow confirmation modal ---
# (function() {
#     if (document.getElementById('unfollow-confirm-modal')) return;
#
#     const modal = document.createElement('div');
#     modal.id = 'unfollow-confirm-modal';
#     modal.className = 'fixed inset-0 z-[100] hidden overflow-y-auto';
#     modal.setAttribute('role', 'dialog');
#     modal.setAttribute('aria-modal', 'true');
#     modal.innerHTML = `
#         <div class="flex items-center justify-center min-h-screen px-4">
#             <div class="fixed inset-0 bg-black/50 transition-opacity" onclick="closeUnfollowModal()"></div>
#             <div class="relative bg-white dark:bg-gray-800 rounded-2xl shadow-xl max-w-sm w-full p-6 text-center z-10">
#                 <div class="w-12 h-12 mx-auto mb-3 rounded-full bg-red-100 dark:bg-red-900/30 flex items-center justify-center">
#                     <i class="fas fa-user-minus text-red-500 dark:text-red-400 text-lg"></i>
#                 </div>
#                 <h3 class="text-lg font-semibold text-gray-900 dark:text-white mb-1">
#                     Dejar de seguir a <span id="unfollow-confirm-username" class="text-primary"></span>?
#                 </h3>
#                 <p class="text-sm text-gray-500 dark:text-gray-400 mb-5">
#                     Ya no verás sus publicaciones en tu feed de seguidos.
#                 </p>
#                 <div class="flex space-x-3">
#                     <button onclick="closeUnfollowModal()"
#                             class="flex-1 px-4 py-2.5 bg-gray-100 dark:bg-gray-700 text-gray-700 dark:text-gray-300 rounded-xl font-medium hover:bg-gray-200 dark:hover:bg-gray-600 transition-colors cursor-pointer">
#                         Cancelar
#                     </button>
#                     <button id="unfollow-confirm-btn"
#                             class="flex-1 px-4 py-2.5 bg-red-500 text-white rounded-xl font-medium hover:bg-red-600 transition-colors cursor-pointer">
#                         Dejar de seguir
#                     </button>
#                 </div>
#             </div>
#         </div>
#     `;
#     document.body.appendChild(modal);
# })();
#
# // Pending unfollow callback
# let _unfollowCallback = null;
#
# function showUnfollowConfirm(username, callback) {
#     _unfollowCallback = callback;
#     const modal = document.getElementById('unfollow-confirm-modal');
#     const usernameEl = document.getElementById('unfollow-confirm-username');
#     const confirmBtn = document.getElementById('unfollow-confirm-btn');
#
#     usernameEl.textContent = '@' + username;
#     modal.classList.remove('hidden');
#
#     // Replace button to remove old listeners
#     const newBtn = confirmBtn.cloneNode(true);
#     confirmBtn.parentNode.replaceChild(newBtn, confirmBtn);
#     newBtn.id = 'unfollow-confirm-btn';
#
#     newBtn.addEventListener('click', function() {
#         const callback = _unfollowCallback;
#         closeUnfollowModal();
#         if (callback) callback();
#     });
# }
#
# function closeUnfollowModal() {
#     const modal = document.getElementById('unfollow-confirm-modal');
#     if (modal) modal.classList.add('hidden');
#     _unfollowCallback = null;
# }
#
# // Close on Escape key
# document.addEventListener('keydown', function(e) {
#     if (e.key === 'Escape') closeUnfollowModal();
# });
#
#
# // --- Core follow API call (shared) ---
# function executeFollowToggle(userId, username, isFollowing, onSuccess, onError) {
#     let csrfTokenElement = document.querySelector('[name="_csrf_token"]') || document.querySelector('[name="csrf_token"]');
#     const csrfToken = csrfTokenElement ? csrfTokenElement.value : '';
#
#     const formData = new FormData();
#     formData.append('user_id', userId);
#     if (csrfToken) formData.append('_csrf_token', csrfToken);
#
#     const headers = { 'X-Requested-With': 'XMLHttpRequest' };
#     if (csrfToken) headers['X-CSRF-Token'] = csrfToken;
#
#     fetch('/user/follow', {
#         method: 'POST',
#         headers: headers,
#         body: formData
#     })
#     .then(response => response.json())
#     .then(data => {
#         if (data.success) {
#             const newState = !isFollowing;
#             if (window.posthog) {
#                 window.posthog.capture(newState ? 'followed_user' : 'unfollowed_user', {
#                     target_user_id: userId,
#                     target_username: username
#                 });
#             }
#             if (onSuccess) onSuccess(data, newState);
#         } else {
#             if (onError) onError();
#         }
#     })
#     .catch(function() {
#         if (onError) onError();
#     });
# }
#
#
# // --- toggleFollowBtn: used by suggested-profiles & feed-follow-suggestions ---
# function toggleFollowBtn(button) {
#     const userId = button.getAttribute('data-user-id');
#     const username = button.getAttribute('data-username');
#     const isFollowing = button.getAttribute('data-following') === 'true';
#     const icon = button.querySelector('i');
#
#     if (isFollowing) {
#         showUnfollowConfirm(username, function() {
#             _doToggleFollowBtn(button, userId, username, isFollowing, icon);
#         });
#         return;
#     }
#
#     _doToggleFollowBtn(button, userId, username, isFollowing, icon);
# }
#
# function _doToggleFollowBtn(button, userId, username, isFollowing, icon) {
#     button.disabled = true;
#     if (icon) icon.className = 'fas fa-spinner fa-spin text-sm';
#
#     executeFollowToggle(userId, username, isFollowing,
#         function(data, newState) {
#             // Update ALL buttons for this user across the page
#             document.querySelectorAll('.follow-btn[data-user-id="' + userId + '"]').forEach(function(btn) {
#                 btn.setAttribute('data-following', newState ? 'true' : 'false');
#                 btn.title = newState ? 'Dejar de seguir' : 'Seguir';
#                 const btnIcon = btn.querySelector('i');
#                 if (btnIcon) btnIcon.className = 'fas ' + (newState ? 'fa-check' : 'fa-plus') + ' text-sm';
#
#                 if (newState) {
#                     btn.classList.remove('bg-primary', 'text-white', 'hover:bg-primary-dark');
#                     btn.classList.add('bg-gray-200', 'dark:bg-gray-600', 'text-gray-600', 'dark:text-gray-300', 'hover:bg-gray-300', 'dark:hover:bg-gray-500');
#                 } else {
#                     btn.classList.remove('bg-gray-200', 'dark:bg-gray-600', 'text-gray-600', 'dark:text-gray-300', 'hover:bg-gray-300', 'dark:hover:bg-gray-500');
#                     btn.classList.add('bg-primary', 'text-white', 'hover:bg-primary-dark');
#                 }
#             });
#             button.disabled = false;
#         },
#         function() {
#             if (icon) icon.className = 'fas ' + (isFollowing ? 'fa-check' : 'fa-plus') + ' text-sm';
#             button.disabled = false;
#         }
#     );
# }
# </script> <script defer="" src="/assets/js/game/apila-platos.js?v=be2dadd6"></script> <script defer="" src="/assets/js/game/idle-trigger.js?v=be2dadd6"></script> </body> </html>
